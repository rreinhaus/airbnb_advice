# %%
import pandas as pd
import numpy as np
import ast
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.preprocessing import OneHotEncoder

df = pd.read_csv('../raw_data/listings.csv')

numeric_col = [
    'neighbourhood_cleansed', 'beds', 'price',
    'availability_365', 'number_of_reviews',
    'review_scores_rating', 'review_scores_accuracy',
    'review_scores_cleanliness', 'review_scores_checkin',
    'review_scores_communication', 'review_scores_location',
    'review_scores_value','latitude', 'longitude','availability_30',
    'host_is_superhost', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'number_of_reviews'
]

data = df[numeric_col]

# %%
data.head()
# Out:
#    neighbourhood_cleansed  beds    price  availability_365  number_of_reviews  \
# 0               Islington   NaN   $65.00               361                 22
# 1  Kensington and Chelsea   1.0   $75.00                 4                 89
# 2             Westminster   3.0  $265.00               295                 43
# 3  Hammersmith and Fulham   1.0  $150.00               364                  0
# 4                  Barnet   NaN   $29.00                 0                129
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.86                    4.80                       4.85
# 1                  4.79                    4.84                       4.88
# 2                  4.69                    4.80                       4.68
# 3                   NaN                     NaN                        NaN
# 4                  4.78                    4.70                       4.94
#
# ...

# %%
data = data[['neighbourhood_cleansed','host_is_superhost','host_response_rate', 'host_acceptance_rate', 'number_of_reviews','number_of_reviews']]

# %%
super_data = data[['host_is_superhost','neighbourhood_cleansed']]

# %%
data.dropna(inplace=True)

# %%
super_data.dropna(inplace=True)
# Out:
# /tmp/ipykernel_7310/1961603509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super_data.dropna(inplace=True)

# %%
data
# Out:
#        neighbourhood_cleansed host_is_superhost host_response_rate  \
# 0                   Islington                 f               100%
# 1      Kensington and Chelsea                 f                67%
# 2                 Westminster                 f                80%
# 5                    Hounslow                 f               100%
# 6        Richmond upon Thames                 f               100%
# ...                       ...               ...                ...
# 66634                   Brent                 t               100%
# 66635                   Brent                 t               100%
# 66636                 Croydon                 t               100%
# 66637                  Ealing                 f               100%
# 66639  Kensington and Chelsea                 f               100%
#
#       host_acceptance_rate  number_of_reviews  number_of_reviews  \
# 0                      85%                 22                 22
# ...

# %%
plt.histplot(super_data['host_is_superhost'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [32], in <module>
# ----> 1 plt.histplot(super_data['host_is_superhost'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'histplot'

# %%
super_data.to_csv('superhost.csv')

# %%
import plotly.express as px 
df=px.data.tips()
fig=px.bar(data[data['neighbourhood_cleansed']== 'Camden'],x='host_response_rate',y='host_acceptance_rate', orientation='h')
fig
# Out:
# <div>                            <div id="8007b4a5-7342-4a7a-9239-98d233f868b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8007b4a5-7342-4a7a-9239-98d233f868b8")) {                    Plotly.newPlot(                        "8007b4a5-7342-4a7a-9239-98d233f868b8",                        [{"alignmentgroup":"True","hovertemplate":"host_response_rate=%{x}<br>host_acceptance_rate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":["56%","100%","33%","75%","0%","100%","100%","100%","100%","75%","100%","100%","100%","100%","100%","100%","100%","100%","100%","100%","100%","90%","100%","100%","100%","90%","100%","100%","100%","
# ...

# %%
# Out:
#       neighbourhood_cleansed host_is_superhost host_response_rate  \
# 26                    Camden                 f                56%
# 30                    Camden                 t               100%
# 64                    Camden                 f                33%
# 65                    Camden                 f                75%
# 75                    Camden                 f                 0%
# ...                      ...               ...                ...
# 66490                 Camden                 f               100%
# 66492                 Camden                 f               100%
# 66526                 Camden                 f               100%
# 66549                 Camden                 t               100%
# 66625                 Camden                 f               100%
#
#       host_acceptance_rate  number_of_reviews  number_of_reviews  \
# 26                     50%                  2                  2
# ...

# %%
fig = px.histogram(data[data['neighbourhood_cleansed']== 'Camden'], x="host_is_superhost")
fig
# Out:
# <div>                            <div id="ce25a283-a990-47aa-a44d-55363f7225b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce25a283-a990-47aa-a44d-55363f7225b3")) {                    Plotly.newPlot(                        "ce25a283-a990-47aa-a44d-55363f7225b3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"host_is_superhost=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["f","t","f","f","f","t","t","t","t","f","f","f","f","t","f","f","f","f","t","f","f","f","f","t","t","f","f","f","f","f","f","f","f","t","f","t","f","f","t","f","f","f","f","t","f","t","f","t","t","f","t","f","t","t","f"
# ...

# %%
|
